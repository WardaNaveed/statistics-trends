# %%
import pandas as pd
import matplotlib.pyplot as plt

#Load Dataset
filename = r'H:\dataset\WorldBank\API_19_DS2_en_csv_v2_5361599.csv'
df = pd.read_csv(filename, skiprows=4)

#Print out the unique values of the 'Indicator Code' column
print(df['Indicator Name'].unique())

#Define the indicators and countries of interest
interest_indicators = ['Urban population', 'Population, total']
interest_countries = ['China', 'German', 'Qatar', 'Russian Federation', 'United Kingdom', 'Cananda', 'Japan']

#Check if the specified indicators are present in the dataset
if not set(interest_indicators).issubset(set(df['Indicator Name'].unique())):
    raise ValueError("Specified indicators are not present in the dataset")

#Subset the data for the indicators and countries of interest
subset = df[(df['Country Name'].isin(interest_countries)) & (df['Indicator Name'].isin(interest_indicators))]
subset = subset[['Country Name', 'Indicator Name', '2020']]

#Rename columns to match indicators
subset = subset.rename(columns={'Indicator Name': 'Indicator', '2020': 'Value'})

#Pivot the data to create separate columns for each indicator
subset = subset.pivot(index='Country Name', columns='Indicator', values='Value')

#Compute summary statistics for the whole world
world_stats = subset.describe()

#Compute summary statistics for each country
country_stats = subset.describe()

#Print the summary statistics
print("Summary statistics for the whole world:")
print(world_stats)

print("\nSummary statistics for each country:")
print(country_stats)
# Out:
# ['Urban population (% of total population)' 'Urban population'
#  'Urban population growth (annual %)' 'Population, total'
#  'Population growth (annual %)'
#  'Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population)'
#  'Prevalence of underweight, weight for age (% of children under 5)'
#  'Community health workers (per 1,000 people)'
#  'Mortality rate, under-5 (per 1,000 live births)'
#  'Primary completion rate, total (% of relevant age group)'
#  'School enrollment, primary and secondary (gross), gender parity index (GPI)'
#  'Agriculture, forestry, and fishing, value added (% of GDP)'
#  'CPIA public sector management and institutions cluster average (1=low to 6=high)'
#  'Ease of doing business rank (1=most business-friendly regulations)'
#  'Terrestrial and marine protected areas (% of total territorial area)'
#  'Marine protected areas (% of territorial waters)'
#  'Terrestrial protected areas (% of total land area)'
# ...

# %%
# Load the dataset and subset to relevant indicators and countries
dataset = pd.read_csv('H:/dataset/WorldBank/API_19_DS2_en_csv_v2_5361599.csv', skiprows=4)
dataset = dataset[dataset['Indicator Code'] == 'EN.ATM.GHGT.KT.CE']
dataset = dataset[dataset['Country Name'].isin(['China', 'Germany', 'Qatar', 'Russian Federation', 'United Kingdom', 'Canada', 'Japan'])]

# Subset to years 1960-2021 in five year increments
subset = dataset.loc[:, ['Country Name', '1960', '1965', '1970', '1975', '1980', '1985', '1990', '1995', '2000', '2005', '2010', '2015', '2020']]


# Pivot the data to create a multi-index DataFrame
df_pivot = subset.set_index('Country Name').stack().reset_index()
df_pivot.columns = ['Country', 'Year', 'Value']
df_pivot = df_pivot.pivot(index='Country', columns='Year', values='Value')

# Plot the bar graph
ax = df_pivot.plot(kind='bar', figsize=(10,6))
ax.set_xlabel('Country Name')
ax.set_ylabel('Greenhouse Gas Emissions (kt of CO2 equivalent)')
ax.set_title('Greenhouse Gas Emissions by Country (kt of CO2 equivalent) (1960-2021)')
plt.show()

# %%
# Load the dataset and subset to relevant indicators and countries
dataset = pd.read_csv('H:/dataset/WorldBank/API_19_DS2_en_csv_v2_5361599.csv', skiprows=4)
dataset = dataset[dataset['Indicator Code'] == 'BX.KLT.DINV.WD.GD.ZS']
dataset = dataset[dataset['Country Name'].isin(['China', 'Germany', 'Qatar', 'Russian Federation', 'United Kingdom', 'Canada', 'Japan'])]

# Subset to years 1960-2021 in five year increments
subset = dataset.loc[:, ['Country Name', '1960', '1965', '1970', '1975', '1980', '1985', '1990', '1995', '2000', '2005', '2010', '2015', '2020']]

# Pivot the data to create a multi-index DataFrame
df_pivot = subset.set_index('Country Name').stack().reset_index()
df_pivot.columns = ['Country', 'Year', 'Value']
df_pivot = df_pivot.pivot(index='Country', columns='Year', values='Value')

# Plot the bar graph
ax = df_pivot.plot(kind='bar', figsize=(10,6))
ax.set_xlabel('Country Name')
ax.set_ylabel('GDP (% of GDP)')
ax.set_title('Foreign Direct Investment (% of GDP) by Country (1960-2021)')
# Out:
# Text(0.5, 1.0, 'Foreign Direct Investment (% of GDP) by Country (1960-2021)')

# %%
# Load the dataset and subset to relevant indicators and countries
dataset = pd.read_csv('H:/dataset/WorldBank/API_19_DS2_en_csv_v2_5361599.csv', skiprows=4)
dataset = dataset[dataset['Indicator Code'] == 'SP.POP.GROW']
dataset = dataset[dataset['Country Name'].isin(['China', 'Germany', 'Qatar', 'Russian Federation', 'United Kingdom', 'Canada', 'Japan'])]

# Subset to years 1960-2021 in five year increments
subset = dataset.loc[:, ['Country Name', '1960', '1965', '1970', '1975', '1980', '1985', '1990', '1995', '2000', '2005', '2010', '2015', '2020']]


# Pivot the data to create a multi-index DataFrame
df_pivot = subset.set_index('Country Name').stack().reset_index()
df_pivot.columns = ['Country', 'Year', 'Value']
df_pivot = df_pivot.pivot(index='Country', columns='Year', values='Value')

# Plot the bar graph
ax = df_pivot.plot(kind='bar', figsize=(10,6))
ax.set_xlabel('Country Name')
ax.set_ylabel('Population Growth')
ax.set_title('Population Growth by Country (1960-2021)')
# Out:
# Text(0.5, 1.0, 'Population Growth by Country (1960-2021)')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('H:/dataset/WorldBank/API_19_DS2_en_csv_v2_5361599.csv', skiprows=4)

# Subset to the indicators of interest
df = df[df['Indicator Code'].isin(['SP.URB.TOTL', 'SP.RUR.TOTL', 'AG.LND.FRST.K2', 'AG.LND.ARBL.HA', 'NY.GDP.MKTP.CD', 'EN.ATM.GHGT.KT.CE', 'EG.USE.COMM.GD.PP.KD'])]

# Subset to Pakistan and years 1960-2020 in 20 year increments
years = list(range(1960, 2021, 20))
df = df.loc[df['Country Code']=='DEU', ['Indicator Code'] + [str(year) for year in years]]

# Pivot the data to create a multi-index DataFrame
df = df.set_index('Indicator Code').stack().reset_index()
df.columns = ['Indicator', 'Year', 'Value']

# Create a pivot table with values by year and indicator
values_pivot = df.pivot(index='Year', columns='Indicator', values='Value')

# Calculate the correlation matrix
corr_matrix = values_pivot.corr()

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Germany')
plt.show()

# %%
#Load the dataset
dataset = pd.read_csv('H:/dataset/WorldBank/API_19_DS2_en_csv_v2_5361599.csv', skiprows=4)
dataset = dataset[dataset['Indicator Code'] == 'AG.LND.FRST.K2']
dataset = dataset[dataset['Country Name'].isin(['China', 'Germany', 'Qatar', 'Russian Federation', 'United Kingdom', 'Canada', 'Japan'])]

#Subset to years 1960-2021 in five year increments
subset = dataset.loc[:, ['Country Name', '1960', '1965', '1970', '1975', '1980', '1985', '1990', '1995', '2000', '2005', '2010', '2015', '2020']]

#Pivot the data to create a multi-index DataFrame
df_pivot = subset.set_index('Country Name').stack().reset_index()
df_pivot.columns = ['Country', 'Year', 'Value']
df_pivot = df_pivot.pivot(index='Country', columns='Year', values='Value')

#Plot the line graph
ax = df_pivot.transpose().plot(figsize=(10,6))
ax.set_xlabel('Year')
ax.set_ylabel('Forest area (sq. km)')
ax.set_title('Forest area  by Country (sq. km) (1960-2021)')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#Load the dataset
dataset = pd.read_csv('H:/dataset/WorldBank/API_19_DS2_en_csv_v2_5361599.csv', skiprows=4)
dataset = dataset[dataset['Indicator Code'] == 'AG.LND.FRST.ZS']
dataset = dataset[dataset['Country Name'].isin(['China', 'Germany', 'Qatar', 'Russian Federation', 'United Kingdom', 'Canada', 'Japan'])]

#Subset to years 1960-2021 in five year increments
subset = dataset.loc[:, ['Country Name', '1960', '1965', '1970', '1975', '1980', '1985', '1990', '1995', '2000', '2005', '2010', '2015', '2020']]

#Pivot the data to create a multi-index DataFrame
df_pivot = subset.set_index('Country Name').stack().reset_index()
df_pivot.columns = ['Country', 'Year', 'Value']
df_pivot = df_pivot.pivot(index='Country', columns='Year', values='Value')

#Plot the line graph
ax = df_pivot.transpose().plot(figsize=(10,6))
ax.set_xlabel('Year')
ax.set_ylabel('Forest area (% of land area)')
ax.set_title('Forest area by Country (% of land area) (1960-2021)')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
# Load the dataset
df = pd.read_csv('H:/dataset/WorldBank/API_19_DS2_en_csv_v2_5361599.csv', skiprows=4)

# Subset to the indicators of interest
df = df[df['Indicator Code'].isin(['SP.URB.TOTL', 'SP.RUR.TOTL', 'AG.LND.FRST.K2', 'AG.LND.ARBL.HA', 'NY.GDP.MKTP.CD', 'EN.ATM.GHGT.KT.CE', 'EG.USE.COMM.GD.PP.KD'])]

# Subset to Pakistan and years 1960-2020 in 20 year increments
years = list(range(1960, 2021, 20))
df = df.loc[df['Country Code']=='QAT', ['Indicator Code'] + [str(year) for year in years]]

# Pivot the data to create a multi-index DataFrame
df = df.set_index('Indicator Code').stack().reset_index()
df.columns = ['Indicator', 'Year', 'Value']

# Create a pivot table with values by year and indicator
values_pivot = df.pivot(index='Year', columns='Indicator', values='Value')

# Calculate the correlation matrix
corr_matrix = values_pivot.corr()

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Qatar')
plt.show()

# %%
# Load the dataset
df = pd.read_csv('H:/dataset/WorldBank/API_19_DS2_en_csv_v2_5361599.csv', skiprows=4)

# Subset to the indicators of interest
df = df[df['Indicator Code'].isin(['SP.URB.TOTL', 'SP.RUR.TOTL', 'AG.LND.FRST.K2', 'AG.LND.ARBL.HA', 'NY.GDP.MKTP.CD', 'EN.ATM.GHGT.KT.CE', 'EG.USE.COMM.GD.PP.KD'])]

# Subset to Pakistan and years 1960-2020 in 20 year increments
years = list(range(1960, 2021, 20))
df = df.loc[df['Country Code']=='GBR', ['Indicator Code'] + [str(year) for year in years]]

# Pivot the data to create a multi-index DataFrame
df = df.set_index('Indicator Code').stack().reset_index()
df.columns = ['Indicator', 'Year', 'Value']

# Create a pivot table with values by year and indicator
values_pivot = df.pivot(index='Year', columns='Indicator', values='Value')

# Calculate the correlation matrix
corr_matrix = values_pivot.corr()

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('United Kingdom')
plt.show()
